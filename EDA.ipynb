# %% [markdown]
# ## 🎯 Exploring Our Dataset

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('sample_dataset.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          NaN         10.38          122.80     1001.0           0.1184
# 1        20.57         17.77          132.90     1326.0              NaN
# 2        19.69         21.25          130.00     1203.0           0.1096
# 3        11.42         20.38           77.58      386.1           0.1425
# 4        20.29         14.34             NaN        NaN              NaN
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0            0.2776          0.3001              0.14710         0.2419
# 1               NaN          0.0869              0.07017            NaN
# 2            0.1599             NaN                  NaN            NaN
# 3            0.2839          0.2414                  NaN         0.2597
# 4            0.1328          0.1980                  NaN         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                 0.07871  ...          17.33              NaN      2019.0
# 1                 0.05667  ...          23.41            158.8      1956.0
# 2                 0.05999  ...          25.53              NaN      1709.0
# 3                 0.09744  ...          26.50              NaN       567.7
# 4                     NaN  ...          16.67            152.2      1575.0
#
#   worst smoothness  worst compactness  worst concavity  worst concave points  \
# 0           0.1622             0.6656           0.7119                0.2654
# 1           0.1238             0.1866           0.2416                0.1860
# 2           0.1444             0.4245           0.4504                0.2430
# 3           0.2098             0.8663           0.6869                0.2575
# 4           0.1374                NaN           0.4000                0.1625
#
#    worst symmetry  worst fractal dimension  target
# 0          0.4601                  0.11890       0
# 1          0.2750                      NaN       0
# 2          0.3613                  0.08758       0
# 3          0.6638                  0.17300       0
# 4          0.2364                  0.07678       0
#
# [5 rows x 31 columns]

# %%
df.dtypes
# Out:
# mean radius                float64
# mean texture               float64
# mean perimeter             float64
# mean area                  float64
# mean smoothness            float64
# mean compactness           float64
# mean concavity             float64
# mean concave points        float64
# mean symmetry              float64
# mean fractal dimension     float64
# radius error               float64
# texture error              float64
# perimeter error            float64
# area error                  object
# smoothness error           float64
# compactness error          float64
# concavity error            float64
# concave points error       float64
# symmetry error             float64
# fractal dimension error    float64
# worst radius               float64
# worst texture              float64
# worst perimeter            float64
# worst area                 float64
# worst smoothness           float64
# worst compactness          float64
# worst concavity            float64
# worst concave points       float64
# worst symmetry             float64
# worst fractal dimension    float64
# target                       int64
# dtype: object

# %%
# to get the unique values in column
df['area error'].unique()
# Out:
# array(['A', nan, 'B', 'C'], dtype=object)

# %%
# number of missing values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   mean radius              482 non-null    float64
#  1   mean texture             492 non-null    float64
#  2   mean perimeter           513 non-null    float64
#  3   mean area                403 non-null    float64
#  4   mean smoothness          384 non-null    float64
#  5   mean compactness         480 non-null    float64
#  6   mean concavity           439 non-null    float64
#  7   mean concave points      382 non-null    float64
#  8   mean symmetry            471 non-null    float64
#  9   mean fractal dimension   504 non-null    float64
#  10  radius error             475 non-null    float64
#  11  texture error            434 non-null    float64
#  12  perimeter error          381 non-null    float64
#  13  area error               494 non-null    object
#  14  smoothness error         492 non-null    float64
#  15  compactness error        456 non-null    float64
#  16  concavity error          379 non-null    float64
#  17  concave points error     507 non-null    float64
#  18  symmetry error           487 non-null    float64
#  19  fractal dimension error  412 non-null    float64
#  20  worst radius             475 non-null    float64
#  21  worst texture            414 non-null    float64
#  22  worst perimeter          460 non-null    float64
#  23  worst area               512 non-null    float64
#  24  worst smoothness         468 non-null    float64
#  25  worst compactness        474 non-null    float64
#  26  worst concavity          507 non-null    float64
#  27  worst concave points     495 non-null    float64
#  28  worst symmetry           410 non-null    float64
#  29  worst fractal dimension  470 non-null    float64
#  30  target                   569 non-null    int64
# dtypes: float64(29), int64(1), object(1)
# memory usage: 137.9+ KB

# %%
# to get the total records in data (rows,columns)
df.shape
# Out:
# (569, 31)

# %%
# Check where are NaN values
df.isna()
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0           True         False           False      False            False
# 1          False         False           False      False             True
# 2          False         False           False      False            False
# 3          False         False           False      False            False
# 4          False         False            True       True             True
# ..           ...           ...             ...        ...              ...
# 564        False         False           False      False            False
# 565         True         False           False      False            False
# 566        False         False           False       True            False
# 567        False         False           False      False            False
# 568        False          True           False      False            False
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0               False           False                False          False
# 1                True           False                False           True
# 2               False            True                 True           True
# 3               False           False                 True          False
# 4               False           False                 True          False
# ..                ...             ...                  ...            ...
# 564              True           False                False          False
# 565             False           False                False          False
# 566             False            True                False          False
# 567             False           False                False          False
# 568             False           False                False          False
#
#      mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                     False  ...          False             True       False
# 1                     False  ...          False            False       False
# 2                     False  ...          False             True       False
# 3                     False  ...          False             True       False
# 4                      True  ...          False            False       False
# ..                      ...  ...            ...              ...         ...
# 564                   False  ...          False            False       False
# 565                    True  ...          False            False       False
# 566                   False  ...          False            False       False
# 567                    True  ...           True            False       False
# 568                   False  ...          False            False        True
#
#      worst smoothness  worst compactness  worst concavity  \
# 0               False              False            False
# 1               False              False            False
# 2               False              False            False
# 3               False              False            False
# 4               False               True            False
# ..                ...                ...              ...
# 564             False              False            False
# 565             False              False            False
# 566             False               True            False
# 567             False              False            False
# 568             False               True            False
#
#      worst concave points  worst symmetry  worst fractal dimension  target
# 0                   False           False                    False   False
# 1                   False           False                     True   False
# 2                   False           False                    False   False
# 3                   False           False                    False   False
# 4                   False           False                    False   False
# ..                    ...             ...                      ...     ...
# 564                 False           False                    False   False
# 565                 False           False                     True   False
# 566                 False           False                    False   False
# 567                 False           False                    False   False
# 568                 False           False                    False   False
#
# [569 rows x 31 columns]

# %% [markdown]
# ### We can count the total number of missing values per column
# ### 🔑 Hint: True is treated as 1, and False as 0 in Python

# %%
df.isna().sum() # Total number of missing values in each column
# Out:
# mean radius                 87
# mean texture                77
# mean perimeter              56
# mean area                  166
# mean smoothness            185
# mean compactness            89
# mean concavity             130
# mean concave points        187
# mean symmetry               98
# mean fractal dimension      65
# radius error                94
# texture error              135
# perimeter error            188
# area error                  75
# smoothness error            77
# compactness error          113
# concavity error            190
# concave points error        62
# symmetry error              82
# fractal dimension error    157
# worst radius                94
# worst texture              155
# worst perimeter            109
# worst area                  57
# worst smoothness           101
# worst compactness           95
# worst concavity             62
# worst concave points        74
# worst symmetry             159
# worst fractal dimension     99
# target                       0
# dtype: int64

# %%
# Percent of missing values in each column

(df.isna().sum()/df.shape[0]).sort_values()
# Out:
# target                     0.000000
# mean perimeter             0.098418
# worst area                 0.100176
# worst concavity            0.108963
# concave points error       0.108963
# mean fractal dimension     0.114236
# worst concave points       0.130053
# area error                 0.131810
# mean texture               0.135325
# smoothness error           0.135325
# symmetry error             0.144112
# mean radius                0.152900
# mean compactness           0.156415
# radius error               0.165202
# worst radius               0.165202
# worst compactness          0.166960
# mean symmetry              0.172232
# worst fractal dimension    0.173989
# worst smoothness           0.177504
# worst perimeter            0.191564
# compactness error          0.198594
# mean concavity             0.228471
# texture error              0.237258
# worst texture              0.272408
# fractal dimension error    0.275923
# worst symmetry             0.279438
# mean area                  0.291740
# mean smoothness            0.325132
# mean concave points        0.328647
# perimeter error            0.330404
# concavity error            0.333919
# dtype: float64

# %%
missing_percentage = (df.isna().mean()*100).sort_values()

# %%
plt.figure(figsize = (8,5))
sns.barplot(x = missing_percentage.index, y = missing_percentage, hue = missing_percentage, palette = 'coolwarm')

plt.ylabel('Percentage of Missing Values')
plt.xlabel('Columns')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # 🎯Summarization

# %%
df.describe()
# Out:
#        mean radius  mean texture  mean perimeter    mean area  \
# count   482.000000    492.000000      513.000000   403.000000
# mean     14.059548     19.311829       92.039025   661.522581
# std       3.501791      4.347769       24.028669   356.669534
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.672500     16.170000       75.270000   428.100000
# 50%      13.280000     18.860000       86.340000   556.700000
# 75%      15.745000     21.802500      104.700000   796.000000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        mean smoothness  mean compactness  mean concavity  mean concave points  \
# count       384.000000        480.000000      439.000000           382.000000
# mean          0.097156          0.104531        0.094063             0.049115
# std           0.014502          0.053335        0.083301             0.038449
# min           0.052630          0.019380        0.000000             0.000000
# 25%           0.086688          0.064815        0.030410             0.020682
# 50%           0.096565          0.093125        0.068240             0.033770
# 75%           0.106825          0.130325        0.135100             0.074122
# max           0.163400          0.345400        0.426800             0.201200
#
#        mean symmetry  mean fractal dimension  ...  worst texture  \
# count     471.000000              504.000000  ...     414.000000
# mean        0.181405                0.062626  ...      25.599058
# std         0.027633                0.007102  ...       6.186596
# min         0.106000                0.049960  ...      12.490000
# 25%         0.161950                0.057530  ...      20.842500
# 50%         0.179100                0.061300  ...      25.225000
# 75%         0.196600                0.066003  ...      29.485000
# max         0.290600                0.097440  ...      49.540000
#
#        worst perimeter   worst area  worst smoothness  worst compactness  \
# count       460.000000   512.000000        468.000000         474.000000
# mean        107.322848   893.873828          0.133065           0.256748
# std          33.967766   587.297571          0.023000           0.160373
# min          54.490000   185.200000          0.071170           0.034320
# 25%          84.147500   510.275000          0.117175           0.144500
# 50%          97.455000   686.550000          0.131450           0.211850
# 75%         126.950000  1141.000000          0.147125           0.343800
# max         251.200000  4254.000000          0.222600           1.058000
#
#        worst concavity  worst concave points  worst symmetry  \
# count       507.000000            495.000000      410.000000
# mean          0.267936              0.116579        0.291797
# std           0.209779              0.066426        0.066327
# min           0.000000              0.000000        0.156600
# 25%           0.106450              0.065280        0.248725
# 50%           0.212300              0.101500        0.282050
# 75%           0.384100              0.165650        0.319750
# max           1.252000              0.291000        0.663800
#
#        worst fractal dimension      target
# count               470.000000  569.000000
# mean                  0.084363    0.627417
# std                   0.018683    0.483918
# min                   0.055040    0.000000
# 25%                   0.071857    0.000000
# 50%                   0.079870    1.000000
# 75%                   0.092172    1.000000
# max                   0.207500    1.000000
#
# [8 rows x 30 columns]

# %%
df.describe(percentiles = [0.05, 0.7, 0.9]) # the percentiles gives the distribution of data
# Out:
#        mean radius  mean texture  mean perimeter    mean area  \
# count   482.000000    492.000000      513.000000   403.000000
# mean     14.059548     19.311829       92.039025   661.522581
# std       3.501791      4.347769       24.028669   356.669534
# min       6.981000      9.710000       43.790000   143.500000
# 5%        9.439400     13.071000       60.922000   279.690000
# 50%      13.280000     18.860000       86.340000   556.700000
# 70%      14.970000     21.301000       98.676000   716.600000
# 90%      19.436000     25.108000      129.100000  1187.600000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        mean smoothness  mean compactness  mean concavity  mean concave points  \
# count       384.000000        480.000000      439.000000           382.000000
# mean          0.097156          0.104531        0.094063             0.049115
# std           0.014502          0.053335        0.083301             0.038449
# min           0.052630          0.019380        0.000000             0.000000
# 5%            0.075221          0.041970        0.004926             0.006431
# 50%           0.096565          0.093125        0.068240             0.033770
# 70%           0.104400          0.122360        0.116340             0.064854
# 90%           0.115560          0.174030        0.211220             0.097101
# max           0.163400          0.345400        0.426800             0.201200
#
#        mean symmetry  mean fractal dimension  ...  worst texture  \
# count     471.000000              504.000000  ...     414.000000
# mean        0.181405                0.062626  ...      25.599058
# std         0.027633                0.007102  ...       6.186596
# min         0.106000                0.049960  ...      12.490000
# 5%          0.140700                0.053783  ...      16.767500
# 50%         0.179100                0.061300  ...      25.225000
# 70%         0.193500                0.064771  ...      28.188000
# 90%         0.214900                0.072144  ...      33.817000
# max         0.290600                0.097440  ...      49.540000
#
#        worst perimeter   worst area  worst smoothness  worst compactness  \
# count       460.000000   512.000000        468.000000         474.000000
# mean        107.322848   893.873828          0.133065           0.256748
# std          33.967766   587.297571          0.023000           0.160373
# min          54.490000   185.200000          0.071170           0.034320
# 5%           67.878000   337.815000          0.097336           0.071879
# 50%          97.455000   686.550000          0.131450           0.211850
# 70%         115.990000   937.600000          0.143490           0.306650
# 90%         158.350000  1722.500000          0.162580           0.460450
# max         251.200000  4254.000000          0.222600           1.058000
#
#        worst concavity  worst concave points  worst symmetry  \
# count       507.000000            495.000000      410.000000
# mean          0.267936              0.116579        0.291797
# std           0.209779              0.066426        0.066327
# min           0.000000              0.000000        0.156600
# 5%            0.014069              0.025448        0.210315
# 50%           0.212300              0.101500        0.282050
# 70%           0.353340              0.153360        0.310900
# 90%           0.562200              0.209920        0.368180
# max           1.252000              0.291000        0.663800
#
#        worst fractal dimension      target
# count               470.000000  569.000000
# mean                  0.084363    0.627417
# std                   0.018683    0.483918
# min                   0.055040    0.000000
# 5%                    0.062888    0.000000
# 50%                   0.079870    1.000000
# 70%                   0.088531    1.000000
# 90%                   0.107240    1.000000
# max                   0.207500    1.000000
#
# [9 rows x 30 columns]

# %%
df.describe(include = ['object']) # categorical data type
# Out:
#        area error
# count         494
# unique          3
# top             A
# freq          489

# %%
df['area error'].value_counts()
# Out:
# area error
# A    489
# B      4
# C      1
# Name: count, dtype: int64

# %%
df.hist();

# %% [markdown]
# ## ⚔️Challenge Loop through all the columns and get the outliers and replace with NaN for each

# %%
def replace_outliers_with_nan(data_table, columns_list):
    cleaned_df = data_table.copy()  # Copy the original DataFrame

    for column in columns_list:
        q1 = cleaned_df[column].quantile(0.25)  # First quartile (25th percentile)
        q3 = cleaned_df[column].quantile(0.75)  # Third quartile (75th percentile)
        IQR = q3 - q1  # Interquartile range

        lower_bound = q1 - 1.5 * IQR  # Lower bound
        upper_bound = q3 + 1.5 * IQR  # Upper bound

        # Replacing only outliers with NaN in that specific column, keeping the rest of the row
        cleaned_df[column] = cleaned_df[column].mask((cleaned_df[column] < lower_bound) | (cleaned_df[column] > upper_bound), None)

    return cleaned_df

# %%
columns = df.select_dtypes(include=['number']).columns.tolist()
columns
# Out:
# ['mean radius',
#  'mean texture',
#  'mean perimeter',
#  'mean area',
#  'mean smoothness',
#  'mean compactness',
#  'mean concavity',
#  'mean concave points',
#  'mean symmetry',
#  'mean fractal dimension',
#  'radius error',
#  'texture error',
#  'perimeter error',
#  'smoothness error',
#  'compactness error',
#  'concavity error',
#  'concave points error',
#  'symmetry error',
#  'fractal dimension error',
#  'worst radius',
#  'worst texture',
#  'worst perimeter',
#  'worst area',
#  'worst smoothness',
#  'worst compactness',
#  'worst concavity',
#  'worst concave points',
#  'worst symmetry',
#  'worst fractal dimension',
#  'target']

# %%
newDF = replace_outliers_with_nan(df,columns)

# %%
newDF
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0            NaN         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0              NaN
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1              NaN
# 4          20.29         14.34             NaN        NaN              NaN
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00        NaN          0.11100
# 565          NaN         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30        NaN          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76           NaN           47.92      181.0              NaN
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0                 NaN             NaN              0.14710         0.2419
# 1                 NaN          0.0869              0.07017            NaN
# 2             0.15990             NaN                  NaN            NaN
# 3                 NaN          0.2414                  NaN            NaN
# 4             0.13280          0.1980                  NaN         0.1809
# ..                ...             ...                  ...            ...
# 564               NaN          0.2439              0.13890         0.1726
# 565           0.10340          0.1440              0.09791         0.1752
# 566           0.10230             NaN              0.05302         0.1590
# 567               NaN             NaN              0.15200         0.2397
# 568           0.04362          0.0000              0.00000         0.1587
#
#      mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                   0.07871  ...          17.33              NaN      2019.0
# 1                   0.05667  ...          23.41           158.80      1956.0
# 2                   0.05999  ...          25.53              NaN      1709.0
# 3                       NaN  ...          26.50              NaN       567.7
# 4                       NaN  ...          16.67           152.20      1575.0
# ..                      ...  ...            ...              ...         ...
# 564                 0.05623  ...          26.40           166.10      2027.0
# 565                     NaN  ...          38.25           155.00      1731.0
# 566                 0.05648  ...          34.12           126.70      1124.0
# 567                     NaN  ...            NaN           184.60      1821.0
# 568                 0.05884  ...          30.37            59.16         NaN
#
#     worst smoothness  worst compactness  worst concavity  \
# 0            0.16220                NaN           0.7119
# 1            0.12380             0.1866           0.2416
# 2            0.14440             0.4245           0.4504
# 3                NaN                NaN           0.6869
# 4            0.13740                NaN           0.4000
# ..               ...                ...              ...
# 564          0.14100             0.2113           0.4107
# 565          0.11660             0.1922           0.3215
# 566          0.11390                NaN           0.3403
# 567          0.16500                NaN              NaN
# 568          0.08996                NaN           0.0000
#
#      worst concave points  worst symmetry  worst fractal dimension  target
# 0                  0.2654             NaN                  0.11890       0
# 1                  0.1860          0.2750                      NaN       0
# 2                  0.2430          0.3613                  0.08758       0
# 3                  0.2575             NaN                      NaN       0
# 4                  0.1625          0.2364                  0.07678       0
# ..                    ...             ...                      ...     ...
# 564                0.2216          0.2060                  0.07115       0
# 565                0.1628          0.2572                      NaN       0
# 566                0.1418          0.2218                  0.07820       0
# 567                0.2650          0.4087                      NaN       0
# 568                0.0000          0.2871                  0.07039       1
#
# [569 rows x 31 columns]

# %%
newDF.isna().sum()
# Out:
# mean radius                 98
# mean texture                83
# mean perimeter              66
# mean area                  180
# mean smoothness            190
# mean compactness           105
# mean concavity             146
# mean concave points        194
# mean symmetry              111
# mean fractal dimension      77
# radius error               126
# texture error              151
# perimeter error            213
# area error                  75
# smoothness error           103
# compactness error          136
# concavity error            205
# concave points error        78
# symmetry error             105
# fractal dimension error    181
# worst radius               109
# worst texture              160
# worst perimeter            120
# worst area                  78
# worst smoothness           106
# worst compactness          110
# worst concavity             72
# worst concave points        74
# worst symmetry             177
# worst fractal dimension    121
# target                       0
# dtype: int64

# %%
skew_Dict = {}
columns = newDF.select_dtypes(include = ['number']).columns.tolist()
for col in columns:
    skew_Dict.update({col : newDF[col].skew(numeric_only = True)})
print(skew_Dict)
# Out:
# {'mean radius': 0.603293388298318, 'mean texture': 0.39285413962801935, 'mean perimeter': 0.6272325704295679, 'mean area': 0.9197769344233993, 'mean smoothness': 0.19505230208192725, 'mean compactness': 0.710443272048418, 'mean concavity': 0.9142208962882143, 'mean concave points': 0.8926253064157795, 'mean symmetry': 0.2538093482270744, 'mean fractal dimension': 0.6025886960963803, 'radius error': 1.0134984028623326, 'texture error': 0.5167542866497957, 'perimeter error': 1.0050934283253525, 'smoothness error': 0.6364711508067181, 'compactness error': 0.8092606304079627, 'concavity error': 0.5632687276130033, 'concave points error': 0.3187150944099835, 'symmetry error': 0.7429815665366459, 'fractal dimension error': 0.8118939813153544, 'worst radius': 0.8270625410064483, 'worst texture': 0.3353569306043556, 'worst perimeter': 0.8397291151351309, 'worst area': 1.1333300967788342, 'worst smoothness': 0.19224677238659638, 'worst compactness': 0.7861890737935806, 'worst concavity': 0.7381287188226052, 'worst concave points': 0.47664649578486135, 'worst symmetry': 0.31695046005101407, 'worst fractal dimension': 0.7353355219754362, 'target': -0.5284613207977967}

# %%
sns.kdeplot(newDF['mean symmetry'])
plt.show()

# %%
sns.histplot(newDF['mean radius'],bins = 30, kde = True)
# Out:
# <Axes: xlabel='mean radius', ylabel='Count'>

# %%
plt.figure(figsize=(12, 5))  # Set figure size
plt.suptitle('Before VS After Removing Outliers', fontsize=14, fontweight='bold')  # Main title

# Before Removing Outliers
plt.subplot(1, 2, 1)
sns.histplot(df['mean radius'], bins='rice', kde=True, color='blue')
plt.title('Before Removing Outliers', fontsize=12)
plt.xlabel('Mean Radius', fontsize=10)
plt.ylabel('Count', fontsize=10)
plt.xticks(rotation=45)  # Rotate x-axis labels
plt.grid(True)  # Add grid

# After Removing Outliers
plt.subplot(1, 2, 2)
sns.histplot(newDF['mean radius'], bins='rice', kde=True, color='green')
plt.title('After Removing Outliers', fontsize=12)
plt.xlabel('Mean Radius', fontsize=10)
plt.ylabel('Count', fontsize=10)
plt.xticks(rotation=45)  # Rotate x-axis labels
plt.grid(True)  # Add grid

plt.tight_layout()  # Adjust layout to prevent overlap
plt.show()

# %%
newDF.iloc[:,0:4].hist(); # select all row and first 4 columns

# %% [markdown]
# ## 🧪Experiment with mask() and loc[]
#
# * When replacing outliers in a dataset, it is important to ensure that only the outlier values are replaced with NaN, while the rest of the row remains intact.
# * ⚠️ Issue with .loc[]
# Using .loc[] incorrectly can result in replacing entire rows with NaN, which is not what we want
# * To ensure that only the outlier values are replaced, we use .mask().

# %%
data = {'A': [1, 2, 4, 4, 5],
        'B': [3, 4, 3, 4, 1],
        'C': [5, 6, 7, 8, 9],
        'D': [1, 2, 3, 1, 5]}

data = pd.DataFrame(data)

# %%
data
# Out:
#    A  B  C  D
# 0  1  3  5  1
# 1  2  4  6  2
# 2  4  3  7  3
# 3  4  4  8  1
# 4  5  1  9  5

# %%
data.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
for col in data.columns:
    data.loc[(data[col] > 0) & (data[col] < 2)] = None

# %%
data
# Out:
#      A    B    C    D
# 0  NaN  NaN  NaN  NaN
# 1  2.0  4.0  6.0  2.0
# 2  4.0  3.0  7.0  3.0
# 3  NaN  NaN  NaN  NaN
# 4  NaN  NaN  NaN  NaN

# %%
data1 = {'A': [1, 2, 4, 4, 5],
        'B': [3, 4, 3, 4, 1],
        'C': [5, 6, 7, 8, 9],
        'D': [1, 2, 3, 1, 5]}

data1 = pd.DataFrame(data1)

# %%
for col in data.columns :
    data1[col] = data1[col].mask((data1[col]>0) & (data1[col]<2), None)

# %%
data1
# Out:
#      A    B  C    D
# 0  NaN  3.0  5  NaN
# 1  2.0  4.0  6  2.0
# 2  4.0  3.0  7  3.0
# 3  4.0  4.0  8  NaN
# 4  5.0  NaN  9  5.0

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### END OF EXPERIMENT

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## 🎯Multivariate Analysis

# %%
numeric_columns = newDF.select_dtypes(include = ['number'])

# %%
sns.pairplot(newDF.iloc[:,0:4])

# %%
# We can use differrent kinds like hist and kde for pairplot
# sns.pairplot(newDF.iloc[:,0:4], kind = 'kde'); 
# Remember the the off diagonals are symmetrical hence set corener to True
sns.pairplot(newDF.iloc[:100,:5],corner = True)

# %%
sns.pairplot(newDF, x_vars = newDF.columns[:4],y_vars = newDF.columns[:4], hue = 'target',corner = True)

# %% [markdown]
# ## ⚠️ Multicolinearity in Independent Variables troublesome to our models
